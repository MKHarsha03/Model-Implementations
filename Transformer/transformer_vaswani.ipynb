# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#   Using cached https://download.pytorch.org/whl/sympy-1.13.1-py3-none-any.whl (6.2 MB)
# ...
#    ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 GB ? eta -:--:--
#    ---------------------------------------- 0.0/2.7 GB 1.5 MB/s eta 0:29:51
#    ---------------------------------------- 0.0/2.7 GB 2.8 MB/s eta 0:16:16
#    ---------------------------------------- 0.0/2.7 GB 4.7 MB/s eta 0:09:43
#    ---------------------------------------- 0.0/2.7 GB 8.1 MB/s eta 0:05:37
#    ---------------------------------------- 0.0/2.7 GB 12.2 MB/s eta 0:03:44
#    ---------------------------------------- 0.0/2.7 GB 12.2 MB/s eta 0:03:44
#    ---------------------------------------- 0.0/2.7 GB 12.6 MB/s eta 0:03:35
#    ---------------------------------------- 0.0/2.7 GB 13.0 MB/s eta 0:03:29
# ...

# %%
import torch
from torch import nn
import torch.nn.functional as F

# %%
class ScaledDotProductAttention(nn.Module):
    def __init__(self,d_k):
        super().__init__()
        self.d_k = d_k

    def forward(self,q,k,v,mask=None):
        scores = torch.matmul(q,k.transpose(-2,-1)) / torch.sqrt(torch.tensor(self.d_k))
        if mask is not None:
            scores = scores.masked_fill(mask == 0,-1e9)
        attention_weights = F.softmax(scores,dim=-1)
        output = torch.matmul(attention_weights,v)
        return output,attention_weights

# %%
class MultiheadAttention(nn.Module):
    def __init__(self,h):
        super().__init__()
        self.h = h

    def linearTransform(self,q,k,v):
        weights = torch.rand((b,k.shape[-1],k.shape[-2]))
        b = torch.rand()
        q = torch.dot(q,weights) + b
        k = torch.dot(k,weights) + b
        v = torch.dot(v,weights) + b

        return q,k,v

    def forward(self,q,k,v):
        attn = ScaledDotProductAttention(k.shape[-2])
        multihead = torch.tensor()
        for i in range(self.h):
            head = self.linearTransform(q,k,v)

#Have to work the projections out
